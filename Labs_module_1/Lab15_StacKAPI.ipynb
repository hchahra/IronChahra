# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
#from stackapi import StackAPI
import requests
import json

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
response=requests.get("https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow")
print(response.json())
# Out:
# {'items': [{'tags': ['node.js', 'typescript', 'playwright'], 'owner': {'account_id': 1413722, 'reputation': 1639, 'user_id': 1339826, 'user_type': 'registered', 'accept_rate': 75, 'profile_image': 'https://i.stack.imgur.com/9gzjc.png?s=256&g=1', 'display_name': 'ernest', 'link': 'https://stackoverflow.com/users/1339826/ernest'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1661941860, 'creation_date': 1661941860, 'question_id': 73554545, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73554545/i-get-cannot-use-import-statement-outside-a-module-when-importing-an-exported', 'title': 'I get &quot;Cannot use import statement outside a module&quot; when importing an exported class from a package, but not within that package'}, {'tags': ['php', 'mysql', 'laravel', 'algorithm', 'performance'], 'owner': {'account_id': 15700959, 'reputation': 301, 'user_id': 11329095, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/6c2561b36cb4ab5ca7182eb898277138?s=256&d=identicon&r=PG&f=1', 'display_name': 'Pablo Camara', 'link': 'https://stackoverflow.com/users/11329095/pablo-camara'}, 'is_answered': False, 'view_count': 1, 'answer_count': 0, 'score': 0, 'last_activity_date': 1661941860, 'creation_date': 1661941860, 'question_id': 73554544, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73554544/generating-short-strings-letters-and-numbers-with-lowest-length-possible-for', 'title': 'Generating short strings (letters and numbers) with lowest length possible (for url shortner): Try random or Use pre-generated data set?'}, {'tags': ['c#', 'reactive', 'propertychanged'], 'owner': {'account_id': 16062200, 'reputation': 1, 'user_id': 11592773, 'user_type': 'registered', 'profile_image': 'https://lh6.googleusercontent.com/-qzgcgOhVTZY/AAAAAAAAAAI/AAAAAAAACdA/uKbRAluEJXg/photo.jpg?sz=256', 'display_name': 'Ormad', 'link': 'https://stackoverflow.com/users/11592773/ormad'}, 'is_answered': False, 'view_count': 20, 'answer_count': 0, 'score': 0, 'last_activity_date': 1661941859, 'creation_date': 1661897745, 'last_edit_date': 1661941859, 'question_id': 73548969, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73548969/net-dynamic-data-list', 'title': '.Net Dynamic Data List'}, {'tags': ['excel', 'vba'], 'owner': {'account_id': 23447914, 'reputation': 21, 'user_id': 17504464, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhUCWInFulz2-UL5lnsbQamQl72kgeVeMxs9Kn5zA=k-s256', 'display_name': 'Nguyễn Hữu Quốc', 'link': 'https://stackoverflow.com/users/17504464/nguy%e1%bb%85n-h%e1%bb%afu-qu%e1%bb%91c'}, 'is_answered': True, 'view_count': 33, 'answer_count': 2, 'score': 2, 'last_activity_date': 1661941857, 'creation_date': 1661928111, 'last_edit_date': 1661928838, 'question_id': 73551802, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73551802/print-an-excel-file-using-macro-but-if-the-value-in-one-row-is-0-then-you-skip', 'title': 'Print an excel file using Macro. But if the value in one row is 0 then you skip it'}, {'tags': ['git', 'github', 'visual-studio-code'], 'owner': {'account_id': 5715926, 'reputation': 517, 'user_id': 4516124, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/06af8dea075ac54919f67a8130c27a17?s=256&d=identicon&r=PG&f=1', 'display_name': 'DavidT', 'link': 'https://stackoverflow.com/users/4516124/davidt'}, 'is_answered': True, 'view_count': 17, 'answer_count': 1, 'score': 0, 'last_activity_date': 1661941856, 'creation_date': 1661939562, 'last_edit_date': 1661941184, 'question_id': 73554061, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73554061/can-i-make-local-only-git-repository-without-github-or-similar-is-that-what', 'title': 'Can I make local (only) git repository without Github or similar? Is that what &quot;Initialize Repository&quot; doe ...

# %%
results=(response.json())
res=response.json()
l=res["items"]
l
# Out:
# [{'tags': ['node.js', 'typescript', 'playwright'],
#   'owner': {'account_id': 1413722,
#    'reputation': 1639,
#    'user_id': 1339826,
#    'user_type': 'registered',
#    'accept_rate': 75,
#    'profile_image': 'https://i.stack.imgur.com/9gzjc.png?s=256&g=1',
#    'display_name': 'ernest',
#    'link': 'https://stackoverflow.com/users/1339826/ernest'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941860,
#   'creation_date': 1661941860,
#   'question_id': 73554545,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554545/i-get-cannot-use-import-statement-outside-a-module-when-importing-an-exported',
#   'title': 'I get &quot;Cannot use import statement outside a module&quot; when importing an exported class from a package, but not within that package'},
#  {'tags': ['php', 'mysql', 'laravel', 'algorithm', 'performance'],
#   'owner': {'account_id': 15700959,
#    'reputation': 301,
#    'user_id': 11329095,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/6c2561b36cb4ab5ca7182eb898277138?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Pablo Camara',
#    'link': 'https://stackoverflow.com/users/11329095/pablo-camara'},
#   'is_answered': False,
#   'view_count': 1,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941860,
#   'creation_date': 1661941860,
#   'question_id': 73554544,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554544/generating-short-strings-letters-and-numbers-with-lowest-length-possible-for',
#   'title': 'Generating short strings (letters and numbers) with lowest length possible (for url shortner): Try random or Use pre-generated data set?'},
#  {'tags': ['c#', 'reactive', 'propertychanged'],
#   'owner': {'account_id': 16062200,
#    'reputation': 1,
#    'user_id': 11592773,
#    'user_type': 'registered',
#    'profile_image': 'https://lh6.googleusercontent.com/-qzgcgOhVTZY/AAAAAAAAAAI/AAAAAAAACdA/uKbRAluEJXg/photo.jpg?sz=256',
#    'display_name': 'Ormad',
#    'link': 'https://stackoverflow.com/users/11592773/ormad'},
#   'is_answered': False,
#   'view_count': 20,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941859,
#   'creation_date': 1661897745,
#   'last_edit_date': 1661941859,
#   'question_id': 73548969,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73548969/net-dynamic-data-list',
#   'title': '.Net Dynamic Data List'},
#  {'tags': ['excel', 'vba'],
#   'owner': {'account_id': 23447914,
#    'reputation': 21,
#    'user_id': 17504464,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GhUCWInFulz2-UL5lnsbQamQl72kgeVeMxs9Kn5zA=k-s256',
#    'display_name': 'Nguyễn Hữu Quốc',
#    'link': 'https://stackoverflow.com/users/17504464/nguy%e1%bb%85n-h%e1%bb%afu-qu%e1%bb%91c'},
#   'is_answered': True,
#   'view_count': 33,
#   'answer_count': 2,
#   'score': 2,
#   'last_activity_date': 1661941857,
#   'creation_date': 1661928111,
#   'last_edit_date': 1661928838,
#   'question_id': 73551802,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73551802/print-an-excel-file-using-macro-but-if-the-value-in-one-row-is-0-then-you-skip',
#   'title': 'Print an excel file using Macro. But if the value in one row is 0 then you skip it'},
#  {'tags': ['git', 'github', 'visual-studio-code'],
#   'owner': {'account_id': 5715926,
#    'reputation': 517,
#    'user_id': 4516124,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/06af8dea075ac54919f67a8130c27a17?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'DavidT',
#    'link': 'https://stackoverflow.com/users/4516124/davidt'},
#   'is_answered': True,
#   'view_count': 17,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941856,
#   'creation_date': 1661939562,
#   'last_edit_date': 1661941184,
#   'question_id': 73554061,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554061/can-i-make-local-only-git-repository-without-github-or-similar-is-that-what',
#   'title': 'Can I make local (only) git repository without Github or similar? Is that what &quot;Initialize Repository&quot; does?'},
#  {'tags': ['python', 'numpy', 'scipy', 'signals'],
#   'owner': {'account_id': 25790648,
#    'reputation': 1,
#    'user_id': 19534773,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AItbvmnpTpmZzjgbKHXJHT6e-S1nKeu0Fou8b1RIUgcC=k-s256',
#    'display_name': 'Simon',
#    'link': 'https://stackoverflow.com/users/19534773/simon'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941856,
#   'creation_date': 1661941856,
#   'question_id': 73554543,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554543/is-there-a-way-of-creating-a-rectangular-signal-with-a-given-rising-edge',
#   'title': 'Is there a way of creating a rectangular signal with a given rising edge?'},
#  {'tags': ['c++', 'c++11', 'lambda'],
#   'owner': {'account_id': 429341,
#    'reputation': 52261,
#    'user_id': 812183,
#    'user_type': 'registered',
#    'accept_rate': 77,
#    'profile_image': 'https://www.gravatar.com/avatar/9639bd6ee5dfd07ff05fb848e67e9657?s=256&d=identicon&r=PG',
#    'display_name': 'Anthony Sottile',
#    'link': 'https://stackoverflow.com/users/812183/anthony-sottile'},
#   'is_answered': True,
#   'view_count': 73862,
#   'accepted_answer_id': 16323119,
#   'answer_count': 3,
#   'score': 100,
#   'last_activity_date': 1661941853,
#   'creation_date': 1367428745,
#   'last_edit_date': 1470912976,
#   'question_id': 16323032,
#   'content_license': 'CC BY-SA 3.0',
#   'link': 'https://stackoverflow.com/questions/16323032/why-cant-i-capture-this-by-reference-this-in-lambda',
#   'title': 'Why can&#39;t I capture this by-reference (&#39;&amp;this&#39;) in lambda?'},
#  {'tags': ['python', 'mysql', 'python-3.x', 'flask'],
#   'owner': {'account_id': 25435058,
#    'reputation': 11,
#    'user_id': 19238904,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJzf-prP9WqlzBP7jPTyWdIqv7eWrBakxA6bgYHI=k-s256',
#    'display_name': 'sahil lone',
#    'link': 'https://stackoverflow.com/users/19238904/sahil-lone'},
#   'is_answered': False,
#   'view_count': 8,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941846,
#   'creation_date': 1661941005,
#   'question_id': 73554367,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554367/insert-error-in-a-mysql-query-flask-web-app',
#   'title': 'Insert error in a Mysql query Flask web app'},
#  {'tags': ['c#'],
#   'owner': {'account_id': 10447961,
#    'reputation': 1,
#    'user_id': 7702487,
#    'user_type': 'registered',
#    'profile_image': 'https://lh6.googleusercontent.com/-7poFw173CTw/AAAAAAAAAAI/AAAAAAAAAVA/4tT4ghmttD8/photo.jpg?sz=256',
#    'display_name': 'Jeech',
#    'link': 'https://stackoverflow.com/users/7702487/jeech'},
#   'is_answered': False,
#   'view_count': 59,
#   'answer_count': 1,
#   'score': -2,
#   'last_activity_date': 1661941845,
#   'creation_date': 1661933332,
#   'last_edit_date': 1661941845,
#   'question_id': 73552742,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73552742/how-i-can-write-a-backslash-in-c-when-i-receibe-a-double-backslash',
#   'title': 'How I can write a backslash in C# when i receibe a double backslash?'},
#  {'tags': ['json', 'vb.net'],
#   'owner': {'account_id': 4676329,
#    'reputation': 47,
#    'user_id': 3786542,
#    'user_type': 'registered',
#    'accept_rate': 25,
#    'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'user3786542',
#    'link': 'https://stackoverflow.com/users/3786542/user3786542'},
#   'is_answered': False,
#   'view_count': 20,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941841,
#   'creation_date': 1661901454,
#   'last_edit_date': 1661941841,
#   'question_id': 73549366,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73549366/conversion-from-type-jarray-to-useable-object',
#   'title': 'Conversion from type &#39;JArray&#39; to useable object'},
#  {'tags': ['angular', 'git', 'github'],
#   'owner': {'account_id': 13817318,
#    'reputation': 1,
#    'user_id': 9973634,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/22e18c5cf66078bc2a48cc29487e8120?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Dumitrescu Bogdan',
#    'link': 'https://stackoverflow.com/users/9973634/dumitrescu-bogdan'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941827,
#   'creation_date': 1661941827,
#   'question_id': 73554542,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554542/files-exceeding-the-github-maximum-file-size-on-an-angular-project',
#   'title': 'Files exceeding the github maximum file size on an angular project'},
#  {'tags': ['python', 'image', 'numpy', 'cv2', 'openai-gym'],
#   'owner': {'account_id': 23611383,
#    'reputation': 23,
#    'user_id': 17646343,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJwtfwX1bCmfZ5KtcMPQkEMsB4dGloR-jKn5-suM=k-s256',
#    'display_name': 'user17646343',
#    'link': 'https://stackoverflow.com/users/17646343/user17646343'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941824,
#   'creation_date': 1661941824,
#   'question_id': 73554541,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554541/cv2-imshow-shows-black-screen-then-distorted-screen-then-correct-screen',
#   'title': 'cv2.imshow shows black screen, then distorted screen, then correct screen'},
#  {'tags': ['java', 'spring', 'spring-boot'],
#   'owner': {'account_id': 26206222,
#    'reputation': 1,
#    'user_id': 19885776,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/Yl4WD.jpg?s=256&g=1',
#    'display_name': 'Rejja Kubzek',
#    'link': 'https://stackoverflow.com/users/19885776/rejja-kubzek'},
#   'is_answered': False,
#   'view_count': 29,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941823,
#   'creation_date': 1661937769,
#   'last_edit_date': 1661941823,
#   'question_id': 73553685,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73553685/what-is-the-easiest-way-to-add-a-inside-a-pathparam-name-in-spring-boot',
#   'title': 'What is the easiest way to add a &#39;-&#39; inside a pathParam name in spring boot?'},
#  {'tags': ['jquery', 'twitter-bootstrap', 'twitter-bootstrap-3'],
#   'owner': {'account_id': 452207,
#    'reputation': 816,
#    'user_id': 848513,
#    'user_type': 'registered',
#    'accept_rate': 81,
#    'profile_image': 'https://www.gravatar.com/avatar/f70f270881220638aa7acf8c56cd5560?s=256&d=identicon&r=PG',
#    'display_name': 'kneidels',
#    'link': 'https://stackoverflow.com/users/848513/kneidels'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941821,
#   'creation_date': 1661940858,
#   'last_edit_date': 1661941821,
#   'question_id': 73554332,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554332/hiding-optgroup-doesnt-work-in-safari-iphone',
#   'title': 'Hiding &lt;optgroup&gt; doesnt work in Safari/iphone'},
#  {'tags': ['azure', 'azure-ad-b2c', 'azure-ad-b2c-custom-policy'],
#   'owner': {'account_id': 26031320,
#    'reputation': 1,
#    'user_id': 19737504,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a-/AFdZucrqfgCX_S1BsIT6go8G5QrKnyqxxAGZW-zWX4dgJ_g=k-s256',
#    'display_name': 't_t',
#    'link': 'https://stackoverflow.com/users/19737504/t-t'},
#   'is_answered': False,
#   'view_count': 42,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941817,
#   'creation_date': 1661541891,
#   'question_id': 73505687,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73505687/azure-b2c-email-field-is-blank-in-mfa-method-email',
#   'title': 'Azure B2C: email field is blank in MFA method EMAIL'},
#  {'tags': ['sql', 'sql-server', 'xml', 'tags'],
#   'owner': {'account_id': 26204957,
#    'reputation': 17,
#    'user_id': 19884671,
#    'user_type': 'registered',
#    'profile_image': 'https://graph.facebook.com/6085848658097470/picture?type=large',
#    'display_name': 'Abidemi McAkin Oluka',
#    'link': 'https://stackoverflow.com/users/19884671/abidemi-mcakin-oluka'},
#   'is_answered': False,
#   'view_count': 23,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941812,
#   'creation_date': 1661928265,
#   'last_edit_date': 1661938577,
#   'question_id': 73551824,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73551824/sql-server-stored-procedure-table-to-xml',
#   'title': 'SQL Server stored procedure - Table to XML'},
#  {'tags': ['r'],
#   'owner': {'account_id': 24000235,
#    'reputation': 55,
#    'user_id': 17985256,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJxumSRPFg8tpXcRtibV0tsIuJgo_BPqfFm4Ttoi=k-s256',
#    'display_name': 'Hasan Sohail',
#    'link': 'https://stackoverflow.com/users/17985256/hasan-sohail'},
#   'is_answered': False,
#   'view_count': 13,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941811,
#   'creation_date': 1661940944,
#   'last_edit_date': 1661941811,
#   'question_id': 73554352,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554352/merging-two-datasets-giving-extra-observations',
#   'title': 'Merging two datasets giving extra observations'},
#  {'tags': ['bash', 'docker', 'shell', 'teamcity', 'directory-structure'],
#   'owner': {'account_id': 8495395,
#    'reputation': 175,
#    'user_id': 6370135,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/fJ0qD.png?s=256&g=1',
#    'display_name': 'Sonali Agrawal',
#    'link': 'https://stackoverflow.com/users/6370135/sonali-agrawal'},
#   'is_answered': False,
#   'view_count': 22,
#   'answer_count': 1,
#   'score': 1,
#   'last_activity_date': 1661941811,
#   'creation_date': 1661856853,
#   'question_id': 73541262,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73541262/bad-substitution-error-in-shell-script-while-extracting-directory',
#   'title': 'Bad substitution error in shell script while extracting directory'},
#  {'tags': ['spring-data-elasticsearch'],
#   'owner': {'account_id': 50398,
#    'reputation': 21937,
#    'user_id': 150342,
#    'user_type': 'registered',
#    'accept_rate': 86,
#    'profile_image': 'https://www.gravatar.com/avatar/15059b386eb3a25b97852a9a6e2d20ac?s=256&d=identicon&r=PG',
#    'display_name': 'Colin',
#    'link': 'https://stackoverflow.com/users/150342/colin'},
#   'is_answered': False,
#   'view_count': 17,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941810,
#   'creation_date': 1660582035,
#   'question_id': 73364027,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73364027/how-to-combine-a-multimatchquery-with-a-boolquery-using-spring-data-elastic-sear',
#   'title': 'How to combine a multiMatchQuery with a boolQuery using Spring Data Elastic Search'},
#  {'tags': ['sql-server', 'tsql', 'substring'],
#   'owner': {'account_id': 12900099,
#    'reputation': 35,
#    'user_id': 9329255,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/c8e146ee1da6c4ffe425997617ee95dc?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'john doe',
#    'link': 'https://stackoverflow.com/users/9329255/john-doe'},
#   'is_answered': False,
#   'view_count': 23,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1661941805,
#   'creation_date': 1661939762,
#   'last_edit_date': 1661939844,
#   'question_id': 73554106,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554106/sql-query-to-return-first-word-after',
#   'title': 'SQL query to return first word after -'},
#  {'tags': ['chart.js', 'chartjs-2.6.0'],
#   'owner': {'account_id': 3855048,
#    'reputation': 3606,
#    'user_id': 3194213,
#    'user_type': 'registered',
#    'accept_rate': 99,
#    'profile_image': 'https://www.gravatar.com/avatar/a080874a672cadc7eecd3469b27d3797?s=256&d=identicon&r=PG',
#    'display_name': 'murday1983',
#    'link': 'https://stackoverflow.com/users/3194213/murday1983'},
#   'is_answered': False,
#   'view_count': 2,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941781,
#   'creation_date': 1661941781,
#   'question_id': 73554535,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554535/auto-change-y-axis-labels-directio-chartjs',
#   'title': 'Auto Change Y Axis Labels Directio ChartJs'},
#  {'tags': ['laravel', 'laravel-8', 'laravel-9'],
#   'owner': {'account_id': 19442855,
#    'reputation': 67,
#    'user_id': 14220961,
#    'user_type': 'registered',
#    'profile_image': 'https://i.stack.imgur.com/X9hpA.jpg?s=256&g=1',
#    'display_name': 'mosafir',
#    'link': 'https://stackoverflow.com/users/14220961/mosafir'},
#   'is_answered': False,
#   'view_count': 18,
#   'answer_count': 2,
#   'score': -3,
#   'last_activity_date': 1661941778,
#   'creation_date': 1661930350,
#   'question_id': 73552193,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73552193/laravel8-target-class-app-http-controllers-logincontroller-does-not-exist',
#   'title': 'Laravel8 Target class [App\\Http\\Controllers\\LoginController] does not exist'},
#  {'tags': ['hazelcast', 'hazelcast-cloud'],
#   'owner': {'account_id': 24010692,
#    'reputation': 1,
#    'user_id': 17994324,
#    'user_type': 'registered',
#    'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJz8HDXmvQjtKNHY-SqcFMLE-W7csr6BfJEpUy8=k-s256',
#    'display_name': 'Sravan Reddy',
#    'link': 'https://stackoverflow.com/users/17994324/sravan-reddy'},
#   'is_answered': False,
#   'view_count': 111,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941776,
#   'creation_date': 1649128249,
#   'last_edit_date': 1649156239,
#   'question_id': 71745927,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/71745927/hazelcast-kubernetes-discovery',
#   'title': 'Hazelcast kubernetes discovery'},
#  {'tags': ['android', 'mediastore'],
#   'owner': {'account_id': 12213088,
#    'reputation': 6731,
#    'user_id': 8914336,
#    'user_type': 'registered',
#    'profile_image': 'https://lh5.googleusercontent.com/-3ZiaPSSVtqI/AAAAAAAAAAI/AAAAAAAAAZE/Bpxg5UxWaP0/photo.jpg?sz=256',
#    'display_name': 'coroutineDispatcher',
#    'link': 'https://stackoverflow.com/users/8914336/coroutinedispatcher'},
#   'is_answered': True,
#   'view_count': 20475,
#   'accepted_answer_id': 57737524,
#   'answer_count': 5,
#   'score': 35,
#   'last_activity_date': 1661941774,
#   'creation_date': 1567168571,
#   'last_edit_date': 1575315537,
#   'question_id': 57726896,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/57726896/mediastore-images-media-insertimage-deprecated',
#   'title': 'MediaStore.Images.Media.insertImage deprecated'},
#  {'tags': ['pandas', 'dataframe'],
#   'owner': {'account_id': 17935620,
#    'reputation': 75,
#    'user_id': 13032015,
#    'user_type': 'registered',
#    'profile_image': 'https://lh6.googleusercontent.com/-UwVAe3kkkX0/AAAAAAAAAAI/AAAAAAAAAAA/AKF05nDlMC09sWBWEEYdP47Mibn4fNegdw/photo.jpg?sz=256',
#    'display_name': 'a.WOL7',
#    'link': 'https://stackoverflow.com/users/13032015/a-wol7'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941772,
#   'creation_date': 1661941772,
#   'question_id': 73554531,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554531/pandas-allocation-delegation-of-unique-values-in-a-dataframe-column-to-a-user',
#   'title': 'Pandas allocation / delegation of unique values in a dataframe column to a user from a list'},
#  {'tags': ['typescript'],
#   'owner': {'account_id': 2135174,
#    'reputation': 107,
#    'user_id': 1895147,
#    'user_type': 'registered',
#    'accept_rate': 50,
#    'profile_image': 'https://www.gravatar.com/avatar/7a0b3a380ec02981b8ac9c7452e3e627?s=256&d=identicon&r=PG',
#    'display_name': 'Allan',
#    'link': 'https://stackoverflow.com/users/1895147/allan'},
#   'is_answered': True,
#   'view_count': 257,
#   'accepted_answer_id': 65749265,
#   'answer_count': 2,
#   'score': 0,
#   'last_activity_date': 1661941772,
#   'creation_date': 1610797352,
#   'question_id': 65749245,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/65749245/typescript-problem-to-loop-through-an-array-of-tuple-and-get-specific-values',
#   'title': 'Typescript problem to loop through an array of tuple and get specific values'},
#  {'tags': ['splunk', 'splunk-query', 'splunk-sdk', 'splunk-dashboard'],
#   'owner': {'account_id': 107885,
#    'reputation': 7435,
#    'user_id': 286641,
#    'user_type': 'registered',
#    'accept_rate': 84,
#    'profile_image': 'https://www.gravatar.com/avatar/4c26cc999586b87d902ed6ebf115ae5b?s=256&d=identicon&r=PG',
#    'display_name': 'Dave',
#    'link': 'https://stackoverflow.com/users/286641/dave'},
#   'is_answered': True,
#   'view_count': 643,
#   'accepted_answer_id': 69442322,
#   'answer_count': 4,
#   'score': 0,
#   'last_activity_date': 1661941767,
#   'creation_date': 1633197594,
#   'question_id': 69418942,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/69418942/splunk-submit-button-submitbutton-does-not-refresh-dashboard-if-no-inputs-are',
#   'title': 'Splunk submit button (submitButton) does not refresh dashboard if no inputs are changed'},
#  {'tags': ['javascript', 'node.js', 'express', 'server'],
#   'owner': {'account_id': 18803398,
#    'reputation': 302,
#    'user_id': 13713269,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/716c2d3460d8bb0a4d369d7db3e1c7a9?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Tarun Jain',
#    'link': 'https://stackoverflow.com/users/13713269/tarun-jain'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941750,
#   'creation_date': 1661941750,
#   'question_id': 73554529,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554529/middleware-was-called-twice-in-single-request',
#   'title': 'Middleware was called twice in single request'},
#  {'tags': ['vim', 'syntax', 'fizzbuzz'],
#   'owner': {'account_id': 7905804,
#    'reputation': 105,
#    'user_id': 5971357,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/432229f62164ac342e6b46b3e03a46af?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'Andreas Nasman',
#    'link': 'https://stackoverflow.com/users/5971357/andreas-nasman'},
#   'is_answered': False,
#   'view_count': 3,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1661941750,
#   'creation_date': 1661941750,
#   'question_id': 73554528,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554528/vim-syntax-explanation-of-remember-fizzbuzz-vimgolf-challenge',
#   'title': 'Vim syntax explanation of &#39;Remember FizzBuzz?&#39; VimGolf challenge'},
#  {'tags': ['r', 'dplyr', 'k-means'],
#   'owner': {'account_id': 13947170,
#    'reputation': 435,
#    'user_id': 10071648,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/577149f27bcf8520e955af83d508b646?s=256&d=identicon&r=PG&f=1',
#    'display_name': 'FPL',
#    'link': 'https://stackoverflow.com/users/10071648/fpl'},
#   'is_answered': False,
#   'view_count': 7,
#   'answer_count': 1,
#   'score': 0,
#   'last_activity_date': 1661941749,
#   'creation_date': 1661940706,
#   'question_id': 73554303,
#   'content_license': 'CC BY-SA 4.0',
#   'link': 'https://stackoverflow.com/questions/73554303/mutating-a-list-of-strings-to-include-k-means-cluster-number-in-r',
#   'title': 'Mutating a list of strings to include K-means cluster number in R'}]

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
for i in results["items"]:
    if "python" in (i["tags"]):
        print(i["title"])
# Out:
# Is there a way of creating a rectangular signal with a given rising edge?
# Insert error in a Mysql query Flask web app
# cv2.imshow shows black screen, then distorted screen, then correct screen

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
for i in results["items"]:
     if "question_id"=="6784" and "question_id"=="6473":
            print('item')
