# %%
# Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
data=pd.read_csv(r'C:\Users\hamit\Desktop\Module2/movie_metadata.csv')

# %%
df=pd.DataFrame(data)
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
import seaborn as sns
pd.crosstab(df["country"],df["movie_title"].count())
#df.groupby(["country"])["movie_title"].count()
# Out:
# col_0                 5043
# country
# Afghanistan              1
# Argentina                4
# Aruba                    1
# Australia               55
# Bahamas                  1
# ...                    ...
# Turkey                   1
# UK                     448
# USA                   3807
# United Arab Emirates     1
# West Germany             3
#
# [65 rows x 1 columns]

# %% [raw]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
df.groupby(["director_name", "genres"])["country"].count()
# Out:
# director_name       genres
# A. Raven Cruz       Action|Adventure|Comedy|Fantasy|Sci-Fi    1
# Aaron Hann          Drama|Horror|Mystery|Sci-Fi|Thriller      1
# Aaron Schneider     Drama|Mystery                             1
# Aaron Seltzer       Comedy|Romance                            1
# Abel Ferrara        Crime|Drama                               1
#                                                              ..
# Zoran Lisinac       Comedy|Music|Romance                      1
# Álex de la Iglesia  Crime|Mystery|Thriller                    1
# Émile Gaudreault    Comedy|Drama                              1
# Éric Tessier        Action|Drama|Horror|Thriller              1
# Étienne Faure       Drama|Musical|Romance                     1
# Name: country, Length: 4464, dtype: int64

# %%
pd.crosstab([df.director_name, df.genres], df.country )
# Out:
# country                                                    Afghanistan  \
# director_name      genres
# A. Raven Cruz      Action|Adventure|Comedy|Fantasy|Sci-Fi            0
# Aaron Hann         Drama|Horror|Mystery|Sci-Fi|Thriller              0
# Aaron Schneider    Drama|Mystery                                     0
# Aaron Seltzer      Comedy|Romance                                    0
# Abel Ferrara       Crime|Drama                                       0
# ...                                                                ...
# Zoran Lisinac      Comedy|Music|Romance                              0
# Álex de la Iglesia Crime|Mystery|Thriller                            0
# Émile Gaudreault   Comedy|Drama                                      0
# Éric Tessier       Action|Drama|Horror|Thriller                      0
# Étienne Faure      Drama|Musical|Romance                             0
#
# country                                                    Argentina  Aruba  \
# ...

# %%
df.groupby(["director_name", "genres"])["movie_title", "country"].count()
# Out:
# C:\Users\hamit\AppData\Local\Temp\ipykernel_14088\3365361526.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["director_name", "genres"])["movie_title", "country"].count()
#                                                            movie_title  \
# director_name      genres
# A. Raven Cruz      Action|Adventure|Comedy|Fantasy|Sci-Fi            1
# Aaron Hann         Drama|Horror|Mystery|Sci-Fi|Thriller              1
# Aaron Schneider    Drama|Mystery                                     1
# Aaron Seltzer      Comedy|Romance                                    1
# Abel Ferrara       Crime|Drama                                       1
# ...                                                                ...
# Zoran Lisinac      Comedy|Music|Romance                              1
# Álex de la Iglesia Crime|Mystery|Thriller                            1
# ...

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
df.groupby(["color"])["duration"].sum()
# Out:
# color
#  Black and White     23461.0
# Color               513913.0
# Name: duration, dtype: float64

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
df["x"]=df["actor_1_facebook_likes"]+df["actor_2_facebook_likes"]+df["actor_3_facebook_likes"]
#df.groupby(["director_name"])["director_facebook_likes"].mean()
x
# Out:
# 0        2791.0
# 1       46000.0
# 2       11554.0
# 3       73000.0
# 4           NaN
#          ...
# 5038     1425.0
# 5039     1753.0
# 5040        0.0
# 5041     2154.0
# 5042      125.0
# Length: 5043, dtype: float64

# %%
df.groupby(["director_name"])["x"].mean()
# Out:
# director_name
# A. Raven Cruz          1094.0
# Aaron Hann              406.0
# Aaron Schneider       16970.0
# Aaron Seltzer          4598.0
# Abel Ferrara           2198.0
#                        ...
# Zoran Lisinac           870.0
# Álex de la Iglesia      702.0
# Émile Gaudreault        917.0
# Éric Tessier             72.0
# Étienne Faure            19.0
# Name: x, Length: 2398, dtype: float64

# %%
import numpy as np
pd.crosstab(df["director_name"], df["x"],aggfunc = np.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [122], in <cell line: 1>()
# ----> 1 pd.crosstab(df["director_name"], df["x"],aggfunc = np.mean())
#
# File <__array_function__ internals>:4, in mean(*args, **kwargs)
#
# TypeError: _mean_dispatcher() missing 1 required positional argument: 'a'

# %%
import phik

# %%
df.corr()
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.258486
# duration                                 0.258486  1.000000
# director_facebook_likes                  0.180674  0.173296
# actor_3_facebook_likes                   0.271646  0.123558
# actor_1_facebook_likes                   0.190016  0.088449
# gross                                    0.480601  0.250298
# num_voted_users                          0.624943  0.314765
# cast_total_facebook_likes                0.263203  0.123074
# facenumber_in_poster                    -0.033897  0.013469
# num_user_for_reviews                     0.609387  0.328403
# budget                                   0.119994  0.074276
# title_year                               0.275707 -0.135038
# actor_2_facebook_likes                   0.282306  0.131673
# imdb_score                               0.305303  0.261662
# aspect_ratio                            -0.049786 -0.090071
# ...
