# %%
pip install stackapi
# Out:
# ...
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt



import wbgapi as wb

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-07-20
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.series.info(q="life")
# Out:
# id                 value
# -----------------  --------------------------------------------------------------
# SH.MMR.RISK        Lifetime risk of maternal death (1 in: rate varies by country)
# SH.MMR.RISK.ZS     Lifetime risk of maternal death (%)
# SP.DYN.LE00.FE.IN  Life expectancy at birth, female (years)
# SP.DYN.LE00.IN     Life expectancy at birth, total (years)
# SP.DYN.LE00.MA.IN  Life expectancy at birth, male (years)
#                    5 elements

# %%
# Current health expenditure/capita= SH.XPD.CHEX.PC.CD
current_health_expenditure_per_capita = wb.data.DataFrame('SH.XPD.CHEX.PC.CD', ['AFW','EAP', 'MEA', 'LAC','CEB'], time=2019)
current_health_expenditure_per_capita
# Out:
#          SH.XPD.CHEX.PC.CD
# economy
# AFW              61.338476
# CEB            1094.749700
# EAP             414.137391
# LAC             642.521080
# MEA             512.764763

# %%
#Mortality rate, under-5 (per 1,000 live births)= SH.DYN.MORT
mortality_rate= wb.data.DataFrame('SH.DYN.MORT', ['AFW','EAP', 'MEA', 'LAC','CEB'], time= (2012,2020))
mortality_rate
# Out:
#              YR2012     YR2020
# economy
# AFW      114.997108  93.627023
# CEB        6.624633   4.745719
# EAP       20.729199  14.437461
# LAC       20.383672  16.039616
# MEA       26.700000  21.300000

# %%
#Life expectancy at birth, total (years)= SP.DYN.LE00.IN
life_expectancy= wb.data.DataFrame('SP.DYN.LE00.IN', ['AFW','EAP', 'MEA', 'LAC','CEB'], time= (2012,2019))
life_expectancy
# Out:
#             YR2012     YR2019
# economy
# AFW      55.138944  58.115723
# CEB      75.993489  77.266844
# EAP      73.647691  75.409703
# LAC      74.325308  75.570176
# MEA      72.931661  74.270874

# %%
g5 = business.sort_values(by=['YR2020'],ascending=True) [:4] 
ax = business.T.plot(color='lightgray', legend=False)
g5.T.plot(ax=ax, figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
d=pd.DataFrame(life_expectancy )

# %%
d.to_csv(r"C:\Users\PC\Desktop\Projet2/projet4.csv")

# %%
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       UMC
# ...
